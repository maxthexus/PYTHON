# %%
print('Escola de Dados da Alura')
print('Nome: Matheus')
print('Sobrenome: Duarte')
print('M')
print('a')
print('t')
print('h')
print('e')
print('u')
print('s')

print(3,  'Maio', 1993)

print('Ano atual: ',2024)
# Out:
# Escola de Dados da Alura
# Nome: Matheus
# Sobrenome: Duarte
# M
# a
# t
# h
# e
# u
# s
# 3 Maio 1993
# Ano atual:  2024
